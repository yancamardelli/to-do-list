# %%
# gerenciador de tarefas
  
tarefas = []  

def adicionar_tarefa(tarefa):  
    tarefas.append(tarefa)  
    print(f'Tarefa "{tarefa}" adicionada com sucesso!')  

def remover_tarefa(index):  
    if 0 <= index < len(tarefas):  
        tarefa_removida = tarefas.pop(index)  
        print(f'Tarefa "{tarefa_removida}" removida com sucesso!')  
    else:  
        print("Índice inválido, tente novamente.")  

def listar_tarefas():  
    if tarefas:  
        print("Lista de Tarefas:")  
        for i, tarefa in enumerate(tarefas):  
            print(f"{i + 1}. {tarefa}")  
    else:  
        print("Nenhuma tarefa na lista.")  

def main():  
    while True:  
        print("\nEscolha uma opção:")  
        print("1. Adicionar Tarefa")  
        print("2. Remover Tarefa")  
        print("3. Listar Tarefas")  
        print("4. Sair")  
        
        opcao = input("Digite o número da opção desejada: ")  

        if opcao == '1':  
            tarefa = input("Digite a tarefa que deseja adicionar: ")  
            adicionar_tarefa(tarefa)  
        elif opcao == '2':  
            listar_tarefas()  
            index = int(input("Digite o número da tarefa para remover: ")) - 1  
            remover_tarefa(index)  
        elif opcao == '3':  
            listar_tarefas()  
        elif opcao == '4':  
            print("Saindo... See you later, bye!")  
            break  
        else:  
            print("Opção inválida, tente novamente.")  

if __name__ == "__main__":  
    main()
# Out:
# Escolha uma opção:
# 1. Adicionar Tarefa
# 2. Remover Tarefa
# 3. Listar Tarefas
# 4. Sair
# Tarefa "Criar um Protifólio" adicionada com sucesso!
#
# Escolha uma opção:
# 1. Adicionar Tarefa
# 2. Remover Tarefa
# 3. Listar Tarefas
# 4. Sair
# Lista de Tarefas:
# 1. Criar um Protifólio
# Tarefa "Criar um Protifólio" removida com sucesso!
#
# Escolha uma opção:
# 1. Adicionar Tarefa
# 2. Remover Tarefa
# 3. Listar Tarefas
# 4. Sair
# Tarefa "Selecionar Projetos" adicionada com sucesso!
#
# Escolha uma opção:
# 1. Adicionar Tarefa
# 2. Remover Tarefa
# 3. Listar Tarefas
# 4. Sair
# Opção inválida. Tente novamente.
#
# Escolha uma opção:
# 1. Adicionar Tarefa
# 2. Remover Tarefa
# 3. Listar Tarefas
# 4. Sair
# Tarefa "Criar portifólio github" adicionada com sucesso!
#
# Escolha uma opção:
# 1. Adicionar Tarefa
# 2. Remover Tarefa
# 3. Listar Tarefas
# 4. Sair
# Tarefa "Estudar pbi" adicionada com sucesso!
#
# Escolha uma opção:
# 1. Adicionar Tarefa
# 2. Remover Tarefa
# 3. Listar Tarefas
# 4. Sair
# Lista de Tarefas:
# 1. Selecionar Projetos
# 2. Criar portifólio github
# 3. Estudar pbi
#
# Escolha uma opção:
# 1. Adicionar Tarefa
# 2. Remover Tarefa
# 3. Listar Tarefas
# 4. Sair
# Lista de Tarefas:
# 1. Selecionar Projetos
# 2. Criar portifólio github
# 3. Estudar pbi
#
# Escolha uma opção:
# 1. Adicionar Tarefa
# 2. Remover Tarefa
# 3. Listar Tarefas
# 4. Sair
# Lista de Tarefas:
# 1. Selecionar Projetos
# 2. Criar portifólio github
# 3. Estudar pbi
# Tarefa "Estudar pbi" removida com sucesso!
#
# Escolha uma opção:
# 1. Adicionar Tarefa
# 2. Remover Tarefa
# 3. Listar Tarefas
# 4. Sair
# Lista de Tarefas:
# 1. Selecionar Projetos
# 2. Criar portifólio github
#
# Escolha uma opção:
# 1. Adicionar Tarefa
# 2. Remover Tarefa
# 3. Listar Tarefas
# 4. Sair
# Saindo... Até logo!
